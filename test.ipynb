# %%
import preproc.get_data as data

# %%
# optional parameter rotate -> get all 4 possible rotations
# optional paramter resize -> resize image to given ratio

x, y = data.get_training_data(rotate=True, resize=(224,224))
x_test = data.get_test_data()

# %%
from metrics.visual import plot

# %%
images = [x_test[0], x_test[1], x_test[2], x_test[3]]

#optioal labels
labels = ['image1', 'image2', 'image3', 'another image']

plot(images, labels)

# %%
images = [x[0], y[0]]

plot(images)
